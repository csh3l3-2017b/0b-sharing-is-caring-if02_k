# %%
import pandas as pd
import math
from random import randint

DataTest = pd.read_csv('D://DataTestFull.csv')
DataTest
# Out:
#         No  Att_1  Att_2  Att_3  Att_4  Label
# 0    B3201     27     49     81     37      0
# 1    B3202     11     32     78     59      0
# 2    B3203     10     21     79     54      0
# 3    B3204     25     53     87     44      0
# 4    B3205     38     68     44     57      0
# 5    B3206     35     79     82     76      1
# 6    B3207     34     87     41     70      1
# 7    B3208     10     53     41     43      0
# 8    B3209     31     62     88     58      1
# 9    B3210     27     55     73     58      0
# 10   B3211     10     44     88     60      0
# 11   B3212     28     64     71     44      0
# 12   B3213     29     41     69     40      0
# 13   B3214     31     81     51     67      0
# 14   B3215     40     73     51     67      1
# 15   B3216     21     97     43     64      1
# 16   B3217     14     29     65     48      0
# 17   B3218     17     65     41     43      0
# 18   B3219     30     90     71     63      1
# ...

# %%
no = []
att1 = []
att2 = []
att3 = []
att4 = []
label_pembanding = []

for i in range(0, len(DataTest)):
    no.append(DataTest.No[i])
    att1.append(DataTest.Att_1[i])
    att2.append(DataTest.Att_2[i])
    att3.append(DataTest.Att_3[i])
    att4.append(DataTest.Att_4[i])
    label_pembanding.append(DataTest.Label[i])
    
for i in range(0, len(DataTest)):
    print(no[i] + " - " + str(att1[i]) + " - " + str(att2[i]) + " - " + str(att3[i]) + " - " + str(att4[i]) + " - " + str(label_pembanding[i]))
# Out:
# B3201 - 27 - 49 - 81 - 37 - 0
# B3202 - 11 - 32 - 78 - 59 - 0
# B3203 - 10 - 21 - 79 - 54 - 0
# B3204 - 25 - 53 - 87 - 44 - 0
# B3205 - 38 - 68 - 44 - 57 - 0
# B3206 - 35 - 79 - 82 - 76 - 1
# B3207 - 34 - 87 - 41 - 70 - 1
# B3208 - 10 - 53 - 41 - 43 - 0
# B3209 - 31 - 62 - 88 - 58 - 1
# B3210 - 27 - 55 - 73 - 58 - 0
# B3211 - 10 - 44 - 88 - 60 - 0
# B3212 - 28 - 64 - 71 - 44 - 0
# B3213 - 29 - 41 - 69 - 40 - 0
# B3214 - 31 - 81 - 51 - 67 - 0
# B3215 - 40 - 73 - 51 - 67 - 1
# B3216 - 21 - 97 - 43 - 64 - 1
# B3217 - 14 - 29 - 65 - 48 - 0
# B3218 - 17 - 65 - 41 - 43 - 0
# B3219 - 30 - 90 - 71 - 63 - 1
# B3220 - 15 - 35 - 41 - 36 - 0
# B3221 - 29 - 91 - 56 - 88 - 0
# B3222 - 35 - 71 - 46 - 71 - 1
# B3223 - 15 - 35 - 40 - 38 - 0
# B3224 - 13 - 32 - 68 - 49 - 0
# B3225 - 21 - 45 - 44 - 40 - 1
# B3226 - 16 - 31 - 88 - 42 - 0
# B3227 - 16 - 61 - 53 - 46 - 0
# B3228 - 27 - 63 - 60 - 31 - 0
# B3229 - 25 - 50 - 40 - 82 - 0
# B3230 - 35 - 77 - 50 - 65 - 1
# B3231 - 11 - 47 - 79 - 70 - 0
# ...

# %%
def tree_1(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att3 >= avg3):
        if(att1 >= avg1):
            if(att4 >= avg4):
                if(att2 >= avg2):
                    return 1
                else:
                    return 0
            else:
                return 0
        else:
            if(att2 >= avg2):
                if(att4 >= avg4):
                    return 1
                else:
                    return 0
            else:
                return 0
    else:
        if(att4 >= avg4):
            if(att2 >= avg2):
                if(att1 >= avg1):
                    return 1
                else:
                    return 0
            else:
                return 0
        else:
            if(att1 >= avg1):
                if(att2 >= avg2):
                    return 1
                else:
                    return 0
            else:
                return 0
            
def tree_2(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att3 >= avg3):
        if(att1 >= avg1):
            if(att4 >= avg4):
                return 1
            else:
                return 0
        else:
            if(att2 >= avg2):
                if(att4 >= avg4):
                    return 1
                else:
                    return 0
            else:
                return 0
    else:
        if(att4 >= avg4):
            if(att2 >= avg2):
                if(att1 >= avg1):
                    return 1
                else:
                    return 0
            else:
                return 0
        else:
            if(att1 >= avg1):
                if(att2 >= avg2):
                    return 1
                else:
                    return 0
            else:
                return 0
            
def tree_3(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att3 >= avg3):
        if(att1 >= avg1):
            if(att4 >= avg4):
                return 1
            else:
                return 0
        else:
            if(att2 >= avg2):
                return 1
            else:
                return 0
    else:
        if(att4 >= avg4):
            if(att2 >= avg2):
                if(att1 >= avg1):
                    return 1
                else:
                    return 0
            else:
                return 0
        else:
            if(att1 >= avg1):
                if(att2 >= avg2):
                    return 1
                else:
                    return 0
            else:
                return 0
            
def tree_4(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att3 >= avg3):
        if(att1 >= avg1):
            if(att4 >= avg4):
                return 1
            else:
                return 0
        else:
            if(att2 >= avg2):
                return 1
            else:
                return 0
    else:
        if(att4 >= avg4):
            if(att2 >= avg2):
                return 1
            else:
                return 0
        else:
            if(att1 >= avg1):
                if(att2 >= avg2):
                    return 1
                else:
                    return 0
            else:
                return 0
            
def tree_5(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att3 >= avg3):
        if(att1 >= avg1):
            if(att4 >= avg4):
                return 1
            else:
                return 0
        else:
            if(att2 >= avg2):
                return 1
            else:
                return 0
    else:
        if(att4 >= avg4):
            if(att2 >= avg2):
                return 1
            else:
                return 0
        else:
            if(att1 >= avg1):
                return 1
            else:
                return 0
            
def tree_6(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att3 >= avg3):
        if(att1 >= avg1):
            return 1
        else:
            if(att2 >= avg2):
                return 1
            else:
                return 0
    else:
        if(att4 >= avg4):
            if(att2 >= avg2):
                return 1
            else:
                return 0
        else:
            if(att1 >= avg1):
                return 1
            else:
                return 0
            
def tree_7(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att3 >= avg3):
        if(att1 >= avg1):
            return 1
        else:
            return 0
    else:
        if(att4 >= avg4):
            if(att2 >= avg2):
                return 1
            else:
                return 0
        else:
            if(att1 >= avg1):
                return 1
            else:
                return 0
            
def tree_8(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att3 >= avg3):
        if(att1 >= avg1):
            return 1
        else:
            return 0
    else:
        if(att4 >= avg4):
            return 1
        else:
            if(att1 >= avg1):
                return 1
            else:
                return 0
            
def tree_9(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att3 >= avg3):
        if(att1 >= avg1):
            return 1
        else:
            return 0
    else:
        if(att4 >= avg4):
            return 1
        else:
            return 0
        
def tree_10(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att3 >= avg3):
        return 1
    else:
        if(att4 >= avg4):
            return 1
        else:
            return 0
        
def tree_11(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att3 >= avg3):
        return 1
    else:
        return 0

# %%
def tree_12(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att1 >= avg1):
        if(att2 >= avg2):
            if(att3 >= avg3):
                if(att4 >= avg4):
                    return 1
                else:
                    return 0
            else:
                return 0
        else:
            if(att4 >= avg4):
                if(att3 >= avg3):
                    return 1
                else:
                    return 0
            else:
                return 0
    else:
        if(att3 >= avg3):
            if(att2 >= avg2):
                if(att4 >= avg4):
                    return 1
                else:
                    return 0
            else:
                return 0
        else:
            if(att4 >= avg4):
                if(att2 >= avg2):
                    return 1
                else:
                    return 0
            else:
                return 0
            
def tree_13(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att1 >= avg1):
        if(att2 >= avg2):
            if(att3 >= avg3):
                return 1
            else:
                return 0
        else:
            if(att4 >= avg4):
                if(att3 >= avg3):
                    return 1
                else:
                    return 0
            else:
                return 0
    else:
        if(att3 >= avg3):
            if(att2 >= avg2):
                if(att4 >= avg4):
                    return 1
                else:
                    return 0
            else:
                return 0
        else:
            if(att4 >= avg4):
                if(att2 >= avg2):
                    return 1
                else:
                    return 0
            else:
                return 0
            
def tree_14(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att1 >= avg1):
        if(att2 >= avg2):
            if(att3 >= avg3):
                return 1
            else:
                return 0
        else:
            if(att4 >= avg4):
                return 1
            else:
                return 0
    else:
        if(att3 >= avg3):
            if(att2 >= avg2):
                if(att4 >= avg4):
                    return 1
                else:
                    return 0
            else:
                return 0
        else:
            if(att4 >= avg4):
                if(att2 >= avg2):
                    return 1
                else:
                    return 0
            else:
                return 0
            
def tree_15(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att1 >= avg1):
        if(att2 >= avg2):
            if(att3 >= avg3):
                return 1
            else:
                return 0
        else:
            if(att4 >= avg4):
                return 1
            else:
                return 0
    else:
        if(att3 >= avg3):
            if(att2 >= avg2):
                return 1
            else:
                return 0
        else:
            if(att4 >= avg4):
                if(att2 >= avg2):
                    return 1
                else:
                    return 0
            else:
                return 0
            
def tree_16(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att1 >= avg1):
        if(att2 >= avg2):
            if(att3 >= avg3):
                return 1
            else:
                return 0
        else:
            if(att4 >= avg4):
                return 1
            else:
                return 0
    else:
        if(att3 >= avg3):
            if(att2 >= avg2):
                return 1
            else:
                return 0
        else:
            if(att4 >= avg4):
                return 1
            else:
                return 0
            
def tree_17(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att1 >= avg1):
        if(att2 >= avg2):
            return 1
        else:
            if(att4 >= avg4):
                return 1
            else:
                return 0
    else:
        if(att3 >= avg3):
            if(att2 >= avg2):
                return 1
            else:
                return 0
        else:
            if(att4 >= avg4):
                return 1
            else:
                return 0
            
def tree_18(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att1 >= avg1):
        if(att2 >= avg2):
            return 1
        else:
            return 0
    else:
        if(att3 >= avg3):
            if(att2 >= avg2):
                return 1
            else:
                return 0
        else:
            if(att4 >= avg4):
                return 1
            else:
                return 0
            
def tree_19(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att1 >= avg1):
        if(att2 >= avg2):
            return 1
        else:
            return 0
    else:
        if(att3 >= avg3):
            return 1
        else:
            if(att4 >= avg4):
                return 1
            else:
                return 0
            
def tree_20(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att1 >= avg1):
        if(att2 >= avg2):
            return 1
        else:
            return 0
    else:
        if(att3 >= avg3):
            return 1
        else:
            return 0
        
def tree_21(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att1 >= avg1):
        return 1
    else:
        if(att3 >= avg3):
            return 1
        else:
            return 0
        
def tree_22(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att1 >= avg1):
        return 1
    else:
        return 0

# %%
def tree_23(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att2 >= avg2):
        if(att1 >= avg1):
            if(att3 >= avg3):
                if(att4 >= avg4):
                    return 1
                else:
                    return 0
            else:
                return 0
        else:
            if(att4 >= avg4):
                if(att3 >= avg3):
                    return 1
                else:
                    return 0
            else:
                return 0
    else:
        if(att3 >= avg3):
            if(att4 >= avg4):
                if(att1 >= avg1):
                    return 1
                else:
                    return 0
            else:
                return 0
        else:
            if(att1 >= avg1):
                if(att4 >= avg4):
                    return 1
                else:
                    return 0
            else:
                return 0
            
def tree_24(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att2 >= avg2):
        if(att1 >= avg1):
            if(att3 >= avg3):
                return 1
            else:
                return 0
        else:
            if(att4 >= avg4):
                if(att3 >= avg3):
                    return 1
                else:
                    return 0
            else:
                return 0
    else:
        if(att3 >= avg3):
            if(att4 >= avg4):
                if(att1 >= avg1):
                    return 1
                else:
                    return 0
            else:
                return 0
        else:
            if(att1 >= avg1):
                if(att4 >= avg4):
                    return 1
                else:
                    return 0
            else:
                return 0
            
def tree_25(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att2 >= avg2):
        if(att1 >= avg1):
            if(att3 >= avg3):
                return 1
            else:
                return 0
        else:
            if(att4 >= avg4):
                return 1
            else:
                return 0
    else:
        if(att3 >= avg3):
            if(att4 >= avg4):
                if(att1 >= avg1):
                    return 1
                else:
                    return 0
            else:
                return 0
        else:
            if(att1 >= avg1):
                if(att4 >= avg4):
                    return 1
                else:
                    return 0
            else:
                return 0
            
def tree_26(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att2 >= avg2):
        if(att1 >= avg1):
            if(att3 >= avg3):
                return 1
            else:
                return 0
        else:
            if(att4 >= avg4):
                return 1
            else:
                return 0
    else:
        if(att3 >= avg3):
            if(att4 >= avg4):
                return 1
            else:
                return 0
        else:
            if(att1 >= avg1):
                if(att4 >= avg4):
                    return 1
                else:
                    return 0
            else:
                return 0
            
def tree_27(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att2 >= avg2):
        if(att1 >= avg1):
            if(att3 >= avg3):
                return 1
            else:
                return 0
        else:
            if(att4 >= avg4):
                return 1
            else:
                return 0
    else:
        if(att3 >= avg3):
            if(att4 >= avg4):
                return 1
            else:
                return 0
        else:
            if(att1 >= avg1):
                return 1
            else:
                return 0
            
def tree_28(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att2 >= avg2):
        if(att1 >= avg1):
            return 1
        else:
            if(att4 >= avg4):
                return 1
            else:
                return 0
    else:
        if(att3 >= avg3):
            if(att4 >= avg4):
                return 1
            else:
                return 0
        else:
            if(att1 >= avg1):
                return 1
            else:
                return 0
            
def tree_29(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att2 >= avg2):
        if(att1 >= avg1):
            return 1
        else:
            return 0
    else:
        if(att3 >= avg3):
            if(att4 >= avg4):
                return 1
            else:
                return 0
        else:
            if(att1 >= avg1):
                return 1
            else:
                return 0
            
def tree_30(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att2 >= avg2):
        if(att1 >= avg1):
            return 1
        else:
            return 0
    else:
        if(att3 >= avg3):
            return 1
        else:
            if(att1 >= avg1):
                return 1
            else:
                return 0
            
def tree_31(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att2 >= avg2):
        if(att1 >= avg1):
            return 1
        else:
            return 0
    else:
        if(att3 >= avg3):
            return 1
        else:
            return 0
        
def tree_32(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att2 >= avg2):
        return 1
    else:
        if(att3 >= avg3):
            return 1
        else:
            return 0
        
def tree_33(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att2 >= avg2):
        return 1
    else:
        return 0

# %%
def tree_34(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att4 >= avg4):
        if(att2 >= avg2):
            if(att3 >= avg3):
                if(att1 >= avg1):
                    return 1
                else:
                    return 0
            else:
                return 0
        else:
            if(att1 >= avg1):
                if(att3 >= avg3):
                    return 1
                else:
                    return 0
            else:
                return 0
    else:
        if(att3 >= avg3):
            if(att1 >= avg1):
                if(att2 >= avg2):
                    return 1
                else:
                    return 0
            else:
                return 0
        else:
            if(att2 >= avg2):
                if(att1 >= avg1):
                    return 1
                else:
                    return 0
            else:
                return 0
            
def tree_35(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att4 >= avg4):
        if(att2 >= avg2):
            if(att3 >= avg3):
                return 1
            else:
                return 0
        else:
            if(att1 >= avg1):
                if(att3 >= avg3):
                    return 1
                else:
                    return 0
            else:
                return 0
    else:
        if(att3 >= avg3):
            if(att1 >= avg1):
                if(att2 >= avg2):
                    return 1
                else:
                    return 0
            else:
                return 0
        else:
            if(att2 >= avg2):
                if(att1 >= avg1):
                    return 1
                else:
                    return 0
            else:
                return 0
            
def tree_36(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att4 >= avg4):
        if(att2 >= avg2):
            if(att3 >= avg3):
                return 1
            else:
                return 0
        else:
            if(att1 >= avg1):
                return 1
            else:
                return 0
    else:
        if(att3 >= avg3):
            if(att1 >= avg1):
                if(att2 >= avg2):
                    return 1
                else:
                    return 0
            else:
                return 0
        else:
            if(att2 >= avg2):
                if(att1 >= avg1):
                    return 1
                else:
                    return 0
            else:
                return 0
            
def tree_37(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att4 >= avg4):
        if(att2 >= avg2):
            if(att3 >= avg3):
                return 1
            else:
                return 0
        else:
            if(att1 >= avg1):
                return 1
            else:
                return 0
    else:
        if(att3 >= avg3):
            if(att1 >= avg1):
                return 1
            else:
                return 0
        else:
            if(att2 >= avg2):
                if(att1 >= avg1):
                    return 1
                else:
                    return 0
            else:
                return 0
            
def tree_38(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att4 >= avg4):
        if(att2 >= avg2):
            if(att3 >= avg3):
                return 1
            else:
                return 0
        else:
            if(att1 >= avg1):
                return 1
            else:
                return 0
    else:
        if(att3 >= avg3):
            if(att1 >= avg1):
                return 1
            else:
                return 0
        else:
            if(att2 >= avg2):
                return 1
            else:
                return 0
            
def tree_39(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att4 >= avg4):
        if(att2 >= avg2):
            return 1
        else:
            if(att1 >= avg1):
                return 1
            else:
                return 0
    else:
        if(att3 >= avg3):
            if(att1 >= avg1):
                return 1
            else:
                return 0
        else:
            if(att2 >= avg2):
                return 1
            else:
                return 0
            
def tree_40(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att4 >= avg4):
        if(att2 >= avg2):
            return 1
        else:
            return 0
    else:
        if(att3 >= avg3):
            if(att1 >= avg1):
                return 1
            else:
                return 0
        else:
            if(att2 >= avg2):
                return 1
            else:
                return 0
            
def tree_41(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att4 >= avg4):
        if(att2 >= avg2):
            return 1
        else:
            return 0
    else:
        if(att3 >= avg3):
            return 1
        else:
            if(att2 >= avg2):
                return 1
            else:
                return 0
            
def tree_42(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att4 >= avg4):
        if(att2 >= avg2):
            return 1
        else:
            return 0
    else:
        if(att3 >= avg3):
            return 1
        else:
            return 0
        
def tree_43(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att2 >= avg2):
        return 1
    else:
        if(att3 >= avg3):
            return 1
        else:
            return 0
        
def tree_44(att1, att2, att3, att4):
    avg1 = 24.64
    avg2 = 58.76
    avg3 = 65.2
    avg4 = 59.38
    
    if(att2 >= avg2):
        return 1
    else:
        return 0

# %%
label = []

for i in range(0, len(DataTest)):
    satu = 0
    vote = []
    
    vote.append(tree_1(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_2(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_3(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_4(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_5(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_6(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_7(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_8(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_9(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_10(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_11(att1[i], att2[i], att3[i], att4[i]))

    vote.append(tree_12(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_13(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_14(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_15(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_16(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_17(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_18(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_19(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_20(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_21(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_22(att1[i], att2[i], att3[i], att4[i]))
    
    vote.append(tree_23(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_24(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_25(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_26(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_27(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_28(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_29(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_30(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_31(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_32(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_33(att1[i], att2[i], att3[i], att4[i]))
    
    vote.append(tree_34(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_35(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_36(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_37(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_38(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_39(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_40(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_41(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_42(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_43(att1[i], att2[i], att3[i], att4[i]))
    vote.append(tree_44(att1[i], att2[i], att3[i], att4[i]))
    
    for j in range(0, len(vote)):
        if(vote[j] == 1):
            satu += 1
    
    if(satu > (len(vote)/2)):
        label.append(1)
    else:
        label.append(0)
        
sama = 0
total = len(label)

for i in range(0, total):
    if(label[i] == label_pembanding[i]):
        sama += 1
        
persentase = (sama / total) * 100

print(str(sama) + " dari " + str(total) + " label sama")
print("Persentase: " + str(round(persentase, 3)) + "%")
# Out:
# 541 dari 800 label sama
# Persentase: 67.625%
